# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
import warnings 
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('50_Startups.csv')
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.columns
# Out:
# Index(['R&D Spend', 'Administration', 'Marketing Spend', 'State', 'Profit'], dtype='object')

# %%
df.describe().transpose()
# Out:
#                  count         mean            std       min          25%  \
# R&D Spend         50.0   73721.6156   45902.256482      0.00   39936.3700
# Administration    50.0  121344.6396   28017.802755  51283.14  103730.8750
# Marketing Spend   50.0  211025.0978  122290.310726      0.00  129300.1325
# Profit            50.0  112012.6392   40306.180338  14681.40   90138.9025
#
#                         50%          75%        max
# R&D Spend         73051.080  101602.8000  165349.20
# Administration   122699.795  144842.1800  182645.56
# Marketing Spend  212716.240  299469.0850  471784.10
# Profit           107978.190  139765.9775  192261.83

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
num_col = df.select_dtypes(include=float)
num_col.head()
# Out:
#    R&D Spend  Administration  Marketing Spend     Profit
# 0  165349.20       136897.80        471784.10  192261.83
# 1  162597.70       151377.59        443898.53  191792.06
# 2  153441.51       101145.55        407934.54  191050.39
# 3  144372.41       118671.85        383199.62  182901.99
# 4  142107.34        91391.77        366168.42  166187.94

# %%
sns.displot(df['R&D Spend'],kde=True)
a = df['R&D Spend'].skew()
print(f'Skewness {a}')
# Out:
# Skewness 0.164002172321177

# %%
sns.displot(df['Administration'],kde=True)
a = df['Administration'].skew()
print(f'Skewness {a}')
# Out:
# Skewness -0.4890248099671768

# %%
sns.displot(df['Marketing Spend'],kde=True)
a = df['Marketing Spend'].skew()
print(f'Skewness {a}')
# Out:
# Skewness -0.04647226758360412

# %%
sns.displot(df['Profit'],kde=True)
a = df['Profit'].skew()
print(f'Skewness {a}')
# Out:
# Skewness 0.023291019769116614

# %%
#checking outliners
sns.boxplot(df)
# Out:
# <Axes: >

# %%
correlation_matrix = df.corr()

# %%
sns.heatmap(correlation_matrix,annot= True)
# Out:
# <Axes: >

# %%
df['State'].unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
encoded = pd.get_dummies(df,columns=['State'])

# %%
encoded
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_California  \
# 0   165349.20       136897.80        471784.10  192261.83                 0
# 1   162597.70       151377.59        443898.53  191792.06                 1
# 2   153441.51       101145.55        407934.54  191050.39                 0
# 3   144372.41       118671.85        383199.62  182901.99                 0
# 4   142107.34        91391.77        366168.42  166187.94                 0
# 5   131876.90        99814.71        362861.36  156991.12                 0
# 6   134615.46       147198.87        127716.82  156122.51                 1
# 7   130298.13       145530.06        323876.68  155752.60                 0
# 8   120542.52       148718.95        311613.29  152211.77                 0
# 9   123334.88       108679.17        304981.62  149759.96                 1
# 10  101913.08       110594.11        229160.95  146121.95                 0
# ...

# %%
Y = df['Profit']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(encoded, Y, test_size=0.33, random_state=42)
x_train.head()
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit  State_California  \
# 46    1315.46       115816.21        297114.46   49490.75                 0
# 47       0.00       135426.92             0.00   42559.73                 1
# 15  114523.61       122616.84        261776.23  129917.04                 0
# 9   123334.88       108679.17        304981.62  149759.96                 1
# 16   78013.11       121597.55        264346.06  126992.93                 1
#
#     State_Florida  State_New York
# 46              1               0
# 47              0               0
# 15              0               1
# 9               0               0
# 16              0               0

# %%
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([ 1.79004051e-16,  0.00000000e+00, -2.22044605e-16,  1.00000000e+00,
#        -1.63314012e-12,  5.30941741e-13,  1.10219838e-12])

# %%
y_pred = lm.predict(x_test)

# %%
# Evaluation 
from sklearn.metrics import mean_squared_error, r2_score
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 2.0085891580111164e-21
# R-squared: 1.0

# %% [markdown]
# # The model is giving 100% accuracy. I think this is because of overfitting.Lets just use cross validation and observe the changes in the accuracy of the model

# %%
from sklearn.model_selection import KFold,cross_val_score

k_folds = KFold(n_splits=5)
scores = cross_val_score(lm,x_train,y_train,cv=k_folds)
print('Cross Validation Scores:', scores)
print('Average of Cross Validation Scores:', scores.mean())
# Out:
# Cross Validation Scores: [1. 1. 1. 1. 1.]
# Average of Cross Validation Scores: 1.0
